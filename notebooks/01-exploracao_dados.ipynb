# %%
import pandas as pd

# Carregar o dataset
df = pd.read_csv('../data/creditcard.csv')

# Exibir informações e primeiras linhas
print(df.info())
print(df.head())

# Exibir as primeiras linhas do dataset
print(df.head())


# Verificar o número de linhas e colunas
print(df.shape)


# Verificar os tipos de dados
print(df.dtypes)


# Resumo estatístico das colunas numéricas
print(df.describe())


# Verificar as primeiras colunas
print(df.head())


# Verificar a presença de valores nulos
print(df.isnull().sum())


#Número de Linhas e Colunas: O dataset possui 284.807 linhas e 31 colunas.
#Tipos de Dados: A maioria das colunas é do tipo float64, com a coluna Class sendo do tipo int64.
#Dados Faltantes: Não há valores nulos no dataset, o que é ótimo.
